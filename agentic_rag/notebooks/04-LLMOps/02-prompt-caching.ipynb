# %%
import instructor
from openai import OpenAI
from pydantic import BaseModel
from typing import Optional

from dotenv import load_dotenv

# %%
load_dotenv()
client = instructor.from_openai(OpenAI())

# %%
text = """
# Global Collaboration Narrative

Section 1. Alice Johnson met Frank Miller in Melbourne before traveling
to London. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Melbourne and compared them with operational reports from
London. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 2. Benjamin Carter met Grace Lee in Sydney before traveling to
Paris. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Sydney and compared them with operational reports from
Paris. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 3. Charlotte Evans met Henry Walker in New York before traveling
to Berlin. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in New York and compared them with operational reports from
Berlin. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 4. Daniel Kim met Isabella Moore in London before traveling to
Tokyo. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in London and compared them with operational reports from
Tokyo. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 5. Emma Wilson met Jack Thompson in Paris before traveling to
Singapore. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Paris and compared them with operational reports from
Singapore. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 6. Frank Miller met Karen Davis in Berlin before traveling to
Toronto. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Berlin and compared them with operational reports from
Toronto. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 7. Grace Lee met Liam Brown in Tokyo before traveling to
Vancouver. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Tokyo and compared them with operational reports from
Vancouver. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 8. Henry Walker met Mia Chen in Singapore before traveling to
San Francisco. The international research program connected
universities, startups, and enterprise laboratories. Every quarter the
participants reviewed architecture, data governance, prompt engineering,
retrieval pipelines, evaluation metrics, caching strategies, and
deployment practices. They documented observations about customer
feedback collected in Singapore and compared them with operational
reports from San Francisco. Each discussion emphasized reproducibility,
careful documentation, transparent assumptions, robust monitoring,
prompt cache validation, retrieval quality, semantic search, version
control, and human review. The resulting handbook became a shared
reference that engineers repeatedly consulted during design reviews,
experiments, benchmarking sessions, release planning, incident analysis,
and post deployment optimization.

Section 9. Isabella Moore met Noah Patel in Toronto before traveling to
Beijing. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Toronto and compared them with operational reports from
Beijing. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 10. Jack Thompson met Olivia Harris in Vancouver before
traveling to Shanghai. The international research program connected
universities, startups, and enterprise laboratories. Every quarter the
participants reviewed architecture, data governance, prompt engineering,
retrieval pipelines, evaluation metrics, caching strategies, and
deployment practices. They documented observations about customer
feedback collected in Vancouver and compared them with operational
reports from Shanghai. Each discussion emphasized reproducibility,
careful documentation, transparent assumptions, robust monitoring,
prompt cache validation, retrieval quality, semantic search, version
control, and human review. The resulting handbook became a shared
reference that engineers repeatedly consulted during design reviews,
experiments, benchmarking sessions, release planning, incident analysis,
and post deployment optimization.

Section 11. Karen Davis met Peter White in San Francisco before
traveling to Seoul. The international research program connected
universities, startups, and enterprise laboratories. Every quarter the
participants reviewed architecture, data governance, prompt engineering,
retrieval pipelines, evaluation metrics, caching strategies, and
deployment practices. They documented observations about customer
feedback collected in San Francisco and compared them with operational
reports from Seoul. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 12. Liam Brown met Queenie Zhang in Beijing before traveling to
Zurich. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Beijing and compared them with operational reports from
Zurich. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 13. Mia Chen met Ryan Scott in Shanghai before traveling to
Dubai. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Shanghai and compared them with operational reports from
Dubai. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 14. Noah Patel met Sophia Turner in Seoul before traveling to
Melbourne. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Seoul and compared them with operational reports from
Melbourne. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 15. Olivia Harris met William Clark in Zurich before traveling
to Sydney. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Zurich and compared them with operational reports from
Sydney. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 16. Peter White met Alice Johnson in Dubai before traveling to
New York. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Dubai and compared them with operational reports from New
York. Each discussion emphasized reproducibility, careful documentation,
transparent assumptions, robust monitoring, prompt cache validation,
retrieval quality, semantic search, version control, and human review.
The resulting handbook became a shared reference that engineers
repeatedly consulted during design reviews, experiments, benchmarking
sessions, release planning, incident analysis, and post deployment
optimization.

Section 17. Queenie Zhang met Benjamin Carter in Melbourne before
traveling to London. The international research program connected
universities, startups, and enterprise laboratories. Every quarter the
participants reviewed architecture, data governance, prompt engineering,
retrieval pipelines, evaluation metrics, caching strategies, and
deployment practices. They documented observations about customer
feedback collected in Melbourne and compared them with operational
reports from London. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 18. Ryan Scott met Charlotte Evans in Sydney before traveling to
Paris. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Sydney and compared them with operational reports from
Paris. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 19. Sophia Turner met Daniel Kim in New York before traveling to
Berlin. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in New York and compared them with operational reports from
Berlin. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 20. William Clark met Emma Wilson in London before traveling to
Tokyo. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in London and compared them with operational reports from
Tokyo. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 21. Alice Johnson met Frank Miller in Paris before traveling to
Singapore. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Paris and compared them with operational reports from
Singapore. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 22. Benjamin Carter met Grace Lee in Berlin before traveling to
Toronto. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Berlin and compared them with operational reports from
Toronto. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 23. Charlotte Evans met Henry Walker in Tokyo before traveling
to Vancouver. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Tokyo and compared them with operational reports from
Vancouver. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 24. Daniel Kim met Isabella Moore in Singapore before traveling
to San Francisco. The international research program connected
universities, startups, and enterprise laboratories. Every quarter the
participants reviewed architecture, data governance, prompt engineering,
retrieval pipelines, evaluation metrics, caching strategies, and
deployment practices. They documented observations about customer
feedback collected in Singapore and compared them with operational
reports from San Francisco. Each discussion emphasized reproducibility,
careful documentation, transparent assumptions, robust monitoring,
prompt cache validation, retrieval quality, semantic search, version
control, and human review. The resulting handbook became a shared
reference that engineers repeatedly consulted during design reviews,
experiments, benchmarking sessions, release planning, incident analysis,
and post deployment optimization.

Section 25. Emma Wilson met Jack Thompson in Toronto before traveling to
Beijing. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Toronto and compared them with operational reports from
Beijing. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 26. Frank Miller met Karen Davis in Vancouver before traveling
to Shanghai. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Vancouver and compared them with operational reports from
Shanghai. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 27. Grace Lee met Liam Brown in San Francisco before traveling
to Seoul. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in San Francisco and compared them with operational reports
from Seoul. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 28. Henry Walker met Mia Chen in Beijing before traveling to
Zurich. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Beijing and compared them with operational reports from
Zurich. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 29. Isabella Moore met Noah Patel in Shanghai before traveling
to Dubai. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Shanghai and compared them with operational reports from
Dubai. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 30. Jack Thompson met Olivia Harris in Seoul before traveling to
Melbourne. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Seoul and compared them with operational reports from
Melbourne. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 31. Karen Davis met Peter White in Zurich before traveling to
Sydney. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Zurich and compared them with operational reports from
Sydney. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 32. Liam Brown met Queenie Zhang in Dubai before traveling to
New York. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Dubai and compared them with operational reports from New
York. Each discussion emphasized reproducibility, careful documentation,
transparent assumptions, robust monitoring, prompt cache validation,
retrieval quality, semantic search, version control, and human review.
The resulting handbook became a shared reference that engineers
repeatedly consulted during design reviews, experiments, benchmarking
sessions, release planning, incident analysis, and post deployment
optimization.

Section 33. Mia Chen met Ryan Scott in Melbourne before traveling to
London. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Melbourne and compared them with operational reports from
London. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 34. Noah Patel met Sophia Turner in Sydney before traveling to
Paris. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Sydney and compared them with operational reports from
Paris. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 35. Olivia Harris met William Clark in New York before traveling
to Berlin. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in New York and compared them with operational reports from
Berlin. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 36. Peter White met Alice Johnson in London before traveling to
Tokyo. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in London and compared them with operational reports from
Tokyo. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 37. Queenie Zhang met Benjamin Carter in Paris before traveling
to Singapore. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Paris and compared them with operational reports from
Singapore. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 38. Ryan Scott met Charlotte Evans in Berlin before traveling to
Toronto. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Berlin and compared them with operational reports from
Toronto. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 39. Sophia Turner met Daniel Kim in Tokyo before traveling to
Vancouver. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Tokyo and compared them with operational reports from
Vancouver. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 40. William Clark met Emma Wilson in Singapore before traveling
to San Francisco. The international research program connected
universities, startups, and enterprise laboratories. Every quarter the
participants reviewed architecture, data governance, prompt engineering,
retrieval pipelines, evaluation metrics, caching strategies, and
deployment practices. They documented observations about customer
feedback collected in Singapore and compared them with operational
reports from San Francisco. Each discussion emphasized reproducibility,
careful documentation, transparent assumptions, robust monitoring,
prompt cache validation, retrieval quality, semantic search, version
control, and human review. The resulting handbook became a shared
reference that engineers repeatedly consulted during design reviews,
experiments, benchmarking sessions, release planning, incident analysis,
and post deployment optimization.

Section 41. Alice Johnson met Frank Miller in Toronto before traveling
to Beijing. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Toronto and compared them with operational reports from
Beijing. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 42. Benjamin Carter met Grace Lee in Vancouver before traveling
to Shanghai. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Vancouver and compared them with operational reports from
Shanghai. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 43. Charlotte Evans met Henry Walker in San Francisco before
traveling to Seoul. The international research program connected
universities, startups, and enterprise laboratories. Every quarter the
participants reviewed architecture, data governance, prompt engineering,
retrieval pipelines, evaluation metrics, caching strategies, and
deployment practices. They documented observations about customer
feedback collected in San Francisco and compared them with operational
reports from Seoul. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 44. Daniel Kim met Isabella Moore in Beijing before traveling to
Zurich. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Beijing and compared them with operational reports from
Zurich. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 45. Emma Wilson met Jack Thompson in Shanghai before traveling
to Dubai. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Shanghai and compared them with operational reports from
Dubai. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 46. Frank Miller met Karen Davis in Seoul before traveling to
Melbourne. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Seoul and compared them with operational reports from
Melbourne. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 47. Grace Lee met Liam Brown in Zurich before traveling to
Sydney. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Zurich and compared them with operational reports from
Sydney. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 48. Henry Walker met Mia Chen in Dubai before traveling to New
York. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Dubai and compared them with operational reports from New
York. Each discussion emphasized reproducibility, careful documentation,
transparent assumptions, robust monitoring, prompt cache validation,
retrieval quality, semantic search, version control, and human review.
The resulting handbook became a shared reference that engineers
repeatedly consulted during design reviews, experiments, benchmarking
sessions, release planning, incident analysis, and post deployment
optimization.

Section 49. Isabella Moore met Noah Patel in Melbourne before traveling
to London. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Melbourne and compared them with operational reports from
London. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.

Section 50. Jack Thompson met Olivia Harris in Sydney before traveling
to Paris. The international research program connected universities,
startups, and enterprise laboratories. Every quarter the participants
reviewed architecture, data governance, prompt engineering, retrieval
pipelines, evaluation metrics, caching strategies, and deployment
practices. They documented observations about customer feedback
collected in Sydney and compared them with operational reports from
Paris. Each discussion emphasized reproducibility, careful
documentation, transparent assumptions, robust monitoring, prompt cache
validation, retrieval quality, semantic search, version control, and
human review. The resulting handbook became a shared reference that
engineers repeatedly consulted during design reviews, experiments,
benchmarking sessions, release planning, incident analysis, and post
deployment optimization.
"""

# %%
def print_usage_and_cost(raw_response):
    
    input_price = 3/1000000
    output_price = 12/1000000
    cached_price = 0.75/1000000

    input_tokens = raw_response.usage.prompt_tokens
    output_tokens = raw_response.usage.completion_tokens
    cached_tokens = raw_response.usage.prompt_tokens_details.cached_tokens
    non_cached_tokens = input_tokens - cached_tokens

    print(f"Input tokens: {input_tokens}")
    print(f"Output tokens: {output_tokens}")
    print(f"Cached tokens: {cached_tokens}")
    print(f"Non-cached tokens: {non_cached_tokens}")

    print(f"Output cost: {output_tokens * output_price}")
    print(f"Cached cost: {cached_tokens * cached_price}")
    print(f"Non-cached cost: {non_cached_tokens * input_price}")

# %% [markdown]
# ### Cache

# %% [markdown]
# #### Execute Twice

# %%
prompt_1 = f"""
Extract names from the following text:

{text}
"""

# %%
prompt_2 = f"""
Extract places from the following text:

{text}
"""

# %%
class ExtractedNames(BaseModel):
    names: list[str]

class ExtractedPlaces(BaseModel):
    places: list[str]

# %%
response_1, raw_response_1 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractedNames,
    messages=[{"role": "system", "content": prompt_1}],
    temperature=0,
)

# %%
response_2, raw_response_2 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractedPlaces,
    messages=[{"role": "system", "content": prompt_2}],
    temperature=0,
)

# %%
raw_response_1.usage
# Out:
# CompletionUsage(completion_tokens=71, prompt_tokens=14815, total_tokens=14886, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=None, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=None), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=14720))

# %%
print_usage_and_cost(raw_response_1)
# Out:
# Input tokens: 14815
# Output tokens: 71
# Cached tokens: 14720
# Non-cached tokens: 95
# Output cost: 0.000852
# Cached cost: 0.01104
# Non-cached cost: 0.000285

# %%
print_usage_and_cost(raw_response_2)
# Out:
# Input tokens: 14815
# Output tokens: 43
# Cached tokens: 14720
# Non-cached tokens: 95
# Output cost: 0.000516
# Cached cost: 0.01104
# Non-cached cost: 0.000285

# %% [markdown]
# ### Prompt Cache

# %% [markdown]
# #### Execute Once

# %%
prompt_3 = f"""
<text>
{text}
</text>

Extract names from the text between <text> and </text> tags.
"""

# %%
prompt_4 = f"""
<text>
{text}
</text>

Extract places from the text between <text> and </text> tags.
"""

# %%
response_3, raw_response_3 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractedPlaces,
    messages=[{"role": "system", "content": prompt_3}],
    temperature=0,
)

# %%
response_4, raw_response_4 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractedPlaces,
    messages=[{"role": "system", "content": prompt_4}],
    temperature=0,
)

# %%
print_usage_and_cost(raw_response_3)
# Out:
# Input tokens: 7852
# Output tokens: 71
# Cached tokens: 7680
# Non-cached tokens: 172
# Output cost: 0.000852
# Cached cost: 0.00576
# Non-cached cost: 0.000516

# %%
print_usage_and_cost(raw_response_4)
# Out:
# Input tokens: 7852
# Output tokens: 43
# Cached tokens: 6912
# Non-cached tokens: 940
# Output cost: 0.000516
# Cached cost: 0.005184
# Non-cached cost: 0.00282

# %% [markdown]
# ### No Prompt Cache

# %%
prompt_3_1 = f"""
Following is the text with more than 2000 tokens.
<text>
{text}
</text>

Extract names from the text between <text> and </text> tags.
"""

# %%
prompt_4_1 = f"""
Following is the text with more than 2000 tokens.
<text>
{text}
</text>

Extract places from the text between <text> and </text> tags.
"""

# %%
response_3_1, raw_response_3_1 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractedPlaces,
    messages=[{"role": "system", "content": prompt_3_1}],
    temperature=0,
)

# %%
response_4_1, raw_response_4_1 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractedPlaces,
    messages=[{"role": "system", "content": prompt_4_1}],
    temperature=0,
)

# %%
print_usage_and_cost(raw_response_3_1)
# Out:
# Input tokens: 7864
# Output tokens: 71
# Cached tokens: 7808
# Non-cached tokens: 56
# Output cost: 0.000852
# Cached cost: 0.005856
# Non-cached cost: 0.00016800000000000002

# %%
print_usage_and_cost(raw_response_4_1)
# Out:
# Input tokens: 7864
# Output tokens: 43
# Cached tokens: 6912
# Non-cached tokens: 952
# Output cost: 0.000516
# Cached cost: 0.005184
# Non-cached cost: 0.002856

# %% [markdown]
# ### Prompt Cache

# %% [markdown]
# #### Same Response Model

# %%
class ExtractionResults(BaseModel):
    names: Optional[list[str]] = None
    places: Optional[list[str]] = None

# %%
prompt_5 = f"""
Following is the text with more than 2000 tokens.
<text>
{text}
</text>

Extract names from the text between <text> and </text> tags, leave places as null.
"""

prompt_6 = f"""
Following is the text with more than 2000 tokens.
<text>
{text}
</text>

Extract places from the text between <text> and </text> tags, leave names as null.
"""

# %%
response_5, raw_response_5 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractionResults,
    messages=[{"role": "system", "content": prompt_5}],
    temperature=0,
)

# %%
response_6, raw_response_6 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractionResults,
    messages=[{"role": "system", "content": prompt_6}],
    temperature=0,
)

# %%
print_usage_and_cost(raw_response_5)
# Out:
# Input tokens: 7890
# Output tokens: 75
# Cached tokens: 6912
# Non-cached tokens: 978
# Output cost: 0.0009
# Cached cost: 0.005184
# Non-cached cost: 0.002934

# %%
print_usage_and_cost(raw_response_6)
# Out:
# Input tokens: 7890
# Output tokens: 47
# Cached tokens: 6912
# Non-cached tokens: 978
# Output cost: 0.000564
# Cached cost: 0.005184
# Non-cached cost: 0.002934

# %% [markdown]
# #### Same Response Model & Same Prompt

# %%
prompt_7 = f"""
Following is the text with more than 2000 tokens.

<text>
{text}
</text>
"""

# %%
response_7, raw_response_7 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractionResults,
    messages=[{"role": "system", "content": prompt_7},
    {"role": "user", "content": "Extract names from the text between <text> and </text> tags, leave places as null."}],
    temperature=0,
)

# %%
response_8, raw_response_8 = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=ExtractionResults,
    messages=[{"role": "system", "content": prompt_7},
    {"role": "user", "content": "Extract places from the text between <text> and </text> tags, leave names as null."}],
    temperature=0,
)

# %%
print_usage_and_cost(raw_response_7)
# Out:
# Input tokens: 7894
# Output tokens: 75
# Cached tokens: 7808
# Non-cached tokens: 86
# Output cost: 0.0009
# Cached cost: 0.005856
# Non-cached cost: 0.000258

# %%
print_usage_and_cost(raw_response_8)
# Out:
# Input tokens: 7894
# Output tokens: 47
# Cached tokens: 7808
# Non-cached tokens: 86
# Output cost: 0.000564
# Cached cost: 0.005856
# Non-cached cost: 0.000258
